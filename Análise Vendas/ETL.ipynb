# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
# Importando Dados
tabela_clientes = pd.read_csv("1-datasets/Clientes.csv", sep=";")
tabela_pedidos = pd.read_csv("1-datasets/Pedidos.csv", sep=";")
tabela_produtos = pd.read_csv("1-datasets/Produtos.csv", sep=";")
tabela_vendas = pd.read_csv("1-datasets/Vendas.csv", sep=";")

# %% [markdown]
# Clientes

# %%
# Exibindo a tabela
tabela_clientes.head()
# Out:
#   ID Cliente      Nome Cliente     Segmento         Cidade           Estado  \
# 0   RH-19495       Rick Hansen   Consumidor  New York City         New York
# 1   JR-16210     Justin Ritter  Corporativo     Wollongong  New South Wales
# 2   CR-12730      Craig Reiter   Consumidor       Brisbane       Queensland
# 3   KM-16375  Katherine Murray       Outros         Berlin           Berlin
# 4    RH-9495       Rick Hansen   Consumidor          Dakar            Dakar
#
#             Pais Mercado   Regiao
# 0  United States      US     East
# 1      Australia    APAC  Oceania
# 2      Australia    APAC  Oceania
# 3        Germany      EU  Central
# 4        Senegal  Africa   Africa

# %%
# Verficando valores nulos
tabela_clientes.isna().sum()
# Out:
# ID Cliente      0
# Nome Cliente    0
# Segmento        0
# Cidade          0
# Estado          0
# Pais            0
# Mercado         0
# Regiao          0
# dtype: int64

# %%
# Verificando duplicatas
total_duplicatas = tabela_clientes.duplicated().sum()
print(f'Total de linhas duplicadas: {total_duplicatas}')
# Out:
# Total de linhas duplicadas: 0

# %%
# Alterando o nome das colunas
tabela_clientes.columns = ['id_cliente', 'nome', 'segmento', 'cidade', 'estado', 'pais', 'mercado', 'regiao']
tabela_clientes.head()
# Out:
#   id_cliente              nome     segmento         cidade           estado  \
# 0   RH-19495       Rick Hansen   Consumidor  New York City         New York
# 1   JR-16210     Justin Ritter  Corporativo     Wollongong  New South Wales
# 2   CR-12730      Craig Reiter   Consumidor       Brisbane       Queensland
# 3   KM-16375  Katherine Murray       Outros         Berlin           Berlin
# 4    RH-9495       Rick Hansen   Consumidor          Dakar            Dakar
#
#             pais mercado   regiao
# 0  United States      US     East
# 1      Australia    APAC  Oceania
# 2      Australia    APAC  Oceania
# 3        Germany      EU  Central
# 4        Senegal  Africa   Africa

# %% [markdown]
# Pedidos

# %%
# Exibindo a tabela
tabela_pedidos.head()
# Out:
#          ID Pedido Data Pedido  Data Envio       Modo Envio Prioridade Pedido
# 0   CA-2012-124891  31-07-2012  31-07-2012        Mesmo Dia           Critico
# 1   CA-2012-124891  31-07-2012  31-07-2012        Mesmo Dia           Critico
# 2    IN-2013-77878  05-02-2013  07-02-2013   Segunda Classe           Critico
# 3    IN-2013-71249  17-10-2013  18-10-2013  Primeira Classe             Medio
# 4  ES-2013-1579342  28-01-2013  30-01-2013  Primeira Classe             Medio

# %%
# Verficando valores nulos
tabela_pedidos.isna().sum()
# Out:
# ID Pedido            0
# Data Pedido          0
# Data Envio           0
# Modo Envio           0
# Prioridade Pedido    0
# dtype: int64

# %%
total_duplicatas = tabela_pedidos.duplicated().sum()
print(f'Total de linhas duplicadas: {total_duplicatas}')
# Out:
# Total de linhas duplicadas: 1

# %%
# removendo linhas duplicadas
tabela_pedidos.drop_duplicates(inplace=True)

# %%
# Verificando novamente se as linhas foram removidas
print(tabela_pedidos.duplicated().sum())
# Out:
# 0

# %%
# Alterando o nome das colunas
tabela_pedidos.columns = ['id_pedido', 'data_pedido', 'data_envio', 'modo_envio', 'prioridade']
tabela_pedidos.head()
# Out:
#          id_pedido data_pedido  data_envio       modo_envio prioridade
# 0   CA-2012-124891  31-07-2012  31-07-2012        Mesmo Dia    Critico
# 2    IN-2013-77878  05-02-2013  07-02-2013   Segunda Classe    Critico
# 3    IN-2013-71249  17-10-2013  18-10-2013  Primeira Classe      Medio
# 4  ES-2013-1579342  28-01-2013  30-01-2013  Primeira Classe      Medio
# 5     SG-2013-4320  05-11-2013  06-11-2013        Mesmo Dia    Critico

# %% [markdown]
# Produtos

# %%
# Exibindo a tabela
tabela_produtos.head()
# Out:
#         ID Produto   Categoria SubCategoria  \
# 0  TEC-AC-10003033  Tecnologia  Accessories
# 1  TEC-AC-10003033  Tecnologia  Accessories
# 2  FUR-CH-10003950      Moveis       Chairs
# 3  TEC-PH-10004664  Tecnologia       Phones
# 4  TEC-PH-10004583  Tecnologia       Phones
#
#                                         Nome Produto
# 0  Plantronics CS510 - Over-the-Head monaural Wir...
# 1  Plantronics CS510 - Over-the-Head monaural Wir...
# 2          Novimex Executive Leather Armchair, Black
# 3                  Nokia Smart Phone, with Caller ID
# 4                     Motorola Smart Phone, Cordless

# %%
# Verficando valores nulos
tabela_produtos.isna().sum()
# Out:
# ID Produto      0
# Categoria       0
# SubCategoria    0
# Nome Produto    0
# dtype: int64

# %%
# Verificando duplicatas
total_duplicatas = tabela_produtos.duplicated().sum()
print(f'Total de linhas duplicadas: {total_duplicatas}')
# Out:
# Total de linhas duplicadas: 1

# %%
# Removendo linhas duplicadas
tabela_produtos.drop_duplicates(inplace=True)

# %%
# Verificando novamente se as linhas foram removidas
print(tabela_produtos.duplicated().sum())
# Out:
# 0

# %%
# Alterando o nome das colunas
tabela_produtos.columns = ['id_produto', 'categoria', 'subcategoria', 'nome_produto']
tabela_produtos.head()
# Out:
#          id_produto   categoria subcategoria  \
# 0   TEC-AC-10003033  Tecnologia  Accessories
# 2   FUR-CH-10003950      Moveis       Chairs
# 3   TEC-PH-10004664  Tecnologia       Phones
# 4   TEC-PH-10004583  Tecnologia       Phones
# 5  TEC-SHA-10000501  Tecnologia      Copiers
#
#                                         nome_produto
# 0  Plantronics CS510 - Over-the-Head monaural Wir...
# 2          Novimex Executive Leather Armchair, Black
# 3                  Nokia Smart Phone, with Caller ID
# 4                     Motorola Smart Phone, Cordless
# 5                     Sharp Wireless Fax, High-Speed

# %% [markdown]
# Vendas

# %%
# Exibindo a tabela
tabela_vendas.head()
# Out:
#             Pedido   Cliente           Produto Valor Venda  \
# 0   CA-2012-124891  RH-19495   TEC-AC-10003033     2309,65
# 1    IN-2013-77878  JR-16210   FUR-CH-10003950    3709,395
# 2    IN-2013-71249  CR-12730   TEC-PH-10004664    5175,171
# 3  ES-2013-1579342  KM-16375   TEC-PH-10004583     2892,51
# 4     SG-2013-4320   RH-9495  TEC-SHA-10000501     2832,96
#
#    Quantidade Vendida Custo Envio
# 0                   7      933,57
# 1                   9      923,63
# 2                   9      915,49
# 3                   5      910,16
# 4                   8      903,04

# %%
# Verificando valores nulos
tabela_vendas.isna().sum()
# Out:
# Pedido                0
# Cliente               0
# Produto               0
# Valor Venda           0
# Quantidade Vendida    0
# Custo Envio           0
# dtype: int64

# %%
# Verificando duplicatas
total_duplicatas = tabela_vendas.duplicated().sum()
print(f'Total de linhas duplicadas: {total_duplicatas}')
# Out:
# Total de linhas duplicadas: 0

# %%
# Alterando o nome das colunas
tabela_vendas.columns = ['id_pedido', 'id_cliente', 'id_produto', 'valor_venda', 'quantidade_vendida', 'custo_envio']
tabela_vendas.head()
# Out:
#          id_pedido id_cliente        id_produto valor_venda  \
# 0   CA-2012-124891   RH-19495   TEC-AC-10003033     2309,65
# 1    IN-2013-77878   JR-16210   FUR-CH-10003950    3709,395
# 2    IN-2013-71249   CR-12730   TEC-PH-10004664    5175,171
# 3  ES-2013-1579342   KM-16375   TEC-PH-10004583     2892,51
# 4     SG-2013-4320    RH-9495  TEC-SHA-10000501     2832,96
#
#    quantidade_vendida custo_envio
# 0                   7      933,57
# 1                   9      923,63
# 2                   9      915,49
# 3                   5      910,16
# 4                   8      903,04

# %% [markdown]
# ### Conectando o MySQL

# %%
# Criando a conexão com MySQL
# Padrão para inserir o caminho: mysql+mysqlconnector://usuario:senha@host/nome_do_banco
engine = create_engine('mysql+mysqlconnector://root:*******/empresa')

# %%
# Enviando os dados
tabela_vendas.to_sql('vendas', con=engine, if_exists='replace', index=False)
tabela_pedidos.to_sql('pedidos', con=engine, if_exists='replace', index=False)
tabela_produtos.to_sql('produtos', con=engine, if_exists='replace', index=False)
tabela_clientes.to_sql('clientes', con=engine, if_exists='replace', index=False)

print(f"Sucesso! {len(tabela_clientes)} linhas inseridas no MySQL mantendo a estrutura original.")
print(f"Sucesso! {len(tabela_pedidos)} linhas inseridas no MySQL mantendo a estrutura original.")
print(f"Sucesso! {len(tabela_produtos)} linhas inseridas no MySQL mantendo a estrutura original.")
print(f"Sucesso! {len(tabela_vendas)} linhas inseridas no MySQL mantendo a estrutura original.")
# Out:
# Sucesso! 1590 linhas inseridas no MySQL mantendo a estrutura original.
# Sucesso! 25035 linhas inseridas no MySQL mantendo a estrutura original.
# Sucesso! 10292 linhas inseridas no MySQL mantendo a estrutura original.
# Sucesso! 51290 linhas inseridas no MySQL mantendo a estrutura original.
